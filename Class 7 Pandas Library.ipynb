# %%
import pandas as pd

# %%
data=pd.read_csv("car.csv")

# %%
data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
data.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
data.sample(10)
# Out:
#                                        name  year  selling_price  km_driven  \
# 207                Fiat Linea T Jet Emotion  2018         890000       1136
# 3502               Maruti Wagon R LXI Minor  2008         150000      50000
# 3058  Mahindra Renault Logan 1.5 DLE Diesel  2007         125000     110000
# 830                     Honda Brio 1.2 S MT  2017         400000      15000
# 2416       Nissan Terrano XV Premium 110 PS  2013         750000      80000
# 328                   Hyundai i20 1.2 Spotz  2017         575000      20000
# 370                  Mahindra XUV500 W8 2WD  2012         600000     200000
# 2121    Hyundai i20 Magna 1.4 CRDi (Diesel)  2013         325000      78000
# 2239                BMW X5 xDrive 30d xLine  2019        4950000      30000
# 556               Hyundai Creta 1.6 CRDi SX  2016         535000      52600
#
#         fuel seller_type transmission         owner
# 207   Petrol      Dealer       Manual   First Owner
# ...

# %%
data['name']
# Out:
# 0                             Maruti 800 AC
# 1                  Maruti Wagon R LXI Minor
# 2                      Hyundai Verna 1.6 SX
# 3                    Datsun RediGO T Option
# 4                     Honda Amaze VX i-DTEC
#                        ...
# 4335    Hyundai i20 Magna 1.4 CRDi (Diesel)
# 4336             Hyundai i20 Magna 1.4 CRDi
# 4337                    Maruti 800 AC BSIII
# 4338       Hyundai Creta 1.6 CRDi SX Option
# 4339                       Renault KWID RXT
# Name: name, Length: 4340, dtype: object

# %%
data.shape
# Out:
# (4340, 8)

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
data.size
# Out:
# 34720

# %%
4340*8
# Out:
# 34720

# %%
df=data[['owner','km_driven','fuel']]

# %%
df.head()
# Out:
#           owner  km_driven    fuel
# 0   First Owner      70000  Petrol
# 1   First Owner      50000  Petrol
# 2   First Owner     100000  Diesel
# 3   First Owner      46000  Petrol
# 4  Second Owner     141000  Diesel

# %%
# Q.1. selling_price <50000

# %%
data[data['selling_price']>100000]
# Out:
#                                      name  year  selling_price  km_driven  \
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# 5                    Maruti Alto LX BSIII  2007         140000     125000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
#Sort the data: km_driven based
data.sort_values(by='km_driven')
# Out:
#                                              name  year  selling_price  \
# 1312                           Mahindra Quanto C6  2014         250000
# 1715                           Ford Figo Titanium  2020         635000
# 1714               Ford Freestyle Titanium Diesel  2020         784000
# 1716            Ford Ecosport 1.5 Diesel Titanium  2020        1000000
# 1291                          Maruti Alto 800 VXI  2020         350000
# ...                                           ...   ...            ...
# 2394          Toyota Innova 2.5 V Diesel 8-seater  2009         350000
# 3679  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2006         400000
# 4184            Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 525             Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 1243                       Maruti Swift VXI BSIII  2009         250000
#
#       km_driven    fuel seller_type transmission           owner
# ...

# %%
#Sort the data: year based
data.sort_values(by='year')
# Out:
#                                     name  year  selling_price  km_driven  \
# 3334                  Maruti 800 AC BSII  1992          50000     100000
# 631             Maruti Gypsy E MG410W ST  1995          95000     100000
# 2972                Mahindra Jeep MM 540  1996         200000      60000
# 61              Mahindra Jeep CL 500 MDI  1996         250000      35000
# 1669            Mahindra Jeep CL 500 MDI  1997         150000     120000
# ...                                  ...   ...            ...        ...
# 2137               Maruti Ertiga 1.5 VDI  2020         550000      90000
# 1432    Hyundai Grand i10 Nios AMT Magna  2020         640000       4000
# 1774           Ford Aspire Titanium BSIV  2020         828999       1010
# 176              Maruti Alto K10 LXI CNG  2020         282000      40000
# 3933  Ford Figo Aspire 1.5 TDCi Titanium  2020         530000      45000
#
#         fuel seller_type transmission                 owner
# ...

# %%
#Sort the data: km_driven based
data.sort_values(by='km_driven', ascending=False)
# Out:
#                                              name  year  selling_price  \
# 1243                       Maruti Swift VXI BSIII  2009         250000
# 4184            Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 525             Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 3679  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2006         400000
# 2394          Toyota Innova 2.5 V Diesel 8-seater  2009         350000
# ...                                           ...   ...            ...
# 3703          Ford EcoSport 1.5 Diesel Trend BSIV  2018         841000
# 1715                           Ford Figo Titanium  2020         635000
# 1716            Ford Ecosport 1.5 Diesel Titanium  2020        1000000
# 1714               Ford Freestyle Titanium Diesel  2020         784000
# 1312                           Mahindra Quanto C6  2014         250000
#
#       km_driven    fuel seller_type transmission           owner
# ...

# %%
#Sort the data: year based
data.sort_values(by='year', ascending=False)
# Out:
#                                    name  year  selling_price  km_driven  \
# 1777     Ford Ecosport 1.5 Petrol Trend  2020        1030000       1010
# 2481         Hyundai Santro Sportz BSIV  2020         520000       5000
# 1595                 Maruti Alto K10 LX  2020         250000       1100
# 2558              Maruti Swift ZXI Plus  2020         550000       5000
# 694   Hyundai Grand i10 Nios Magna CRDi  2020         700000       1400
# ...                                 ...   ...            ...        ...
# 3661                     Maruti 800 Std  1997          50000      80000
# 2972               Mahindra Jeep MM 540  1996         200000      60000
# 61             Mahindra Jeep CL 500 MDI  1996         250000      35000
# 631            Maruti Gypsy E MG410W ST  1995          95000     100000
# 3334                 Maruti 800 AC BSII  1992          50000     100000
#
#         fuel seller_type transmission                 owner
# ...

# %% [markdown]
# # Group by in Data

# %%
data.groupby('seller_type').mean()
# Out:
#                          year  selling_price     km_driven
# seller_type
# Dealer            2014.200201  721822.890342  52827.259557
# Individual        2012.665228  424505.419236  71167.556104
# Trustmark Dealer  2015.813725  914950.980392  39202.215686

# %%
data['fuel'].value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
data.groupby('fuel').mean()
# Out:
#                  year  selling_price     km_driven
# fuel
# CNG       2013.475000  277174.925000  67234.750000
# Diesel    2013.606595  669094.252206  79630.977706
# Electric  2006.000000  310000.000000  62000.000000
# LPG       2010.130435  167826.043478  89634.782609
# Petrol    2012.595855  344840.137541  52340.079604

# %%
df.shape
# Out:
# (4340, 3)

# %%
df.columns
# Out:
# Index(['owner', 'km_driven', 'fuel'], dtype='object')

# %%
data.shape
# Out:
# (4340, 8)

# %% [markdown]
# # Merge two dataframe

# %%
data.merge(df,on='owner')
# Out:
#                              name  year  selling_price  km_driven_x  fuel_x  \
# 0                   Maruti 800 AC  2007          60000        70000  Petrol
# 1                   Maruti 800 AC  2007          60000        70000  Petrol
# 2                   Maruti 800 AC  2007          60000        70000  Petrol
# 3                   Maruti 800 AC  2007          60000        70000  Petrol
# 4                   Maruti 800 AC  2007          60000        70000  Petrol
# ...                           ...   ...            ...          ...     ...
# 9342721  Honda City i-VTEC CVT ZX  2018        1165000        13000  Petrol
# 9342722  Honda City i-VTEC CVT ZX  2018        1165000        13000  Petrol
# 9342723  Honda City i-VTEC CVT ZX  2018        1165000        13000  Petrol
# 9342724  Honda City i-VTEC CVT ZX  2018        1165000        13000  Petrol
# 9342725  Honda City i-VTEC CVT ZX  2018        1165000        13000  Petrol
#
# ...

# %%
data.pivot_table(index='fuel',columns='transmission', values='selling_price')
# Out:
# transmission     Automatic         Manual
# fuel
# CNG                    NaN  277174.925000
# Diesel        1.900102e+06  504441.246445
# Electric      3.100000e+05            NaN
# LPG                    NaN  167826.043478
# Petrol        7.664093e+05  302683.221762

# %% [markdown]
# # Handling missing Values

# %%
data.dropna()
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data.fillna(value=0)
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data.fillna(data.mean())
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_5796\3231489778.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.fillna(data.mean())
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# ...

# %%
t=data['selling_price'][0]

# %%
data['selling_price']=data['selling_price'].astype(str)

# %%
data['selling_price']=data['selling_price'].astype(int)

# %%
t=data['selling_price'][0]

# %%
t
# Out:
# 60000

# %%
type(t)
# Out:
# numpy.int32

# %% [markdown]
# # Apply function

# %%
# data['selling_price'].apply(len)

# %%
def reverse_name(name):
    return name[::-1]

# %%
data['transmission']=data['transmission'].apply(reverse_name)

# %%
data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  lorteP
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  lorteP
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  leseiD
# 3    Datsun RediGO T Option  2017         250000      46000  lorteP
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  leseiD
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  lorteP
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  lorteP
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  leseiD
# 3    Datsun RediGO T Option  2017         250000      46000  lorteP
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  leseiD
#
#   seller_type transmission         owner
# 0  Individual       launaM   First Owner
# 1  Individual       launaM   First Owner
# 2  Individual       launaM   First Owner
# 3  Individual       launaM   First Owner
# 4  Individual       launaM  Second Owner

# %%
data=data[data['selling_price']>10000]

# %%
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data.to_csv('output.csv')

# %%
data.to_excel('output.xlsx',sheet_name='Sheet1')

# %% [markdown]
# # statistics

# %%
data.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
data['year'].mean()
# Out:
# 2013.0907834101383

# %%
data['year'].median()
# Out:
# 2014.0

# %%
data['year'].max()
# Out:
# 2020

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.plot.bar(x='fuel',y='selling_price',title='My Edunock graph....')
# Out:
# <AxesSubplot:title={'center':'My Edunock graph....'}, xlabel='fuel'>

# %%
data.plot.bar(x='transmission',y='year',title='My Edunock graph....')
# Out:
# <AxesSubplot:title={'center':'My Edunock graph....'}, xlabel='transmission'>

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %% [markdown]
# # Indexing and Selection

# %%
data.loc[0]
# Out:
# name             Maruti 800 AC
# year                      2007
# selling_price            60000
# km_driven                70000
# fuel                    lorteP
# seller_type         Individual
# transmission            launaM
# owner              First Owner
# Name: 0, dtype: object

# %%
data.iloc[0:10,0:2]
# Out:
#                         name  year
# 0              Maruti 800 AC  2007
# 1   Maruti Wagon R LXI Minor  2007
# 2       Hyundai Verna 1.6 SX  2012
# 3     Datsun RediGO T Option  2017
# 4      Honda Amaze VX i-DTEC  2014
# 5       Maruti Alto LX BSIII  2007
# 6  Hyundai Xcent 1.2 Kappa S  2016
# 7   Tata Indigo Grand Petrol  2014
# 8   Hyundai Creta 1.6 VTVT S  2015
# 9   Maruti Celerio Green VXI  2017
